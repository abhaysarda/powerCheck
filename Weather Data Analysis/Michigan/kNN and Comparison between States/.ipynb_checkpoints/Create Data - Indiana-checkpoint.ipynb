# %%
import pandas as pd
import pandas_ml as pdml
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
#Load data
df = pd.read_csv('Indianapolis Airport.csv');
df = df.fillna(0);
df.describe()
# Out:
#        Average Wind Speed  Precipitation         TMAX         TMIN  \
# count         2921.000000    2921.000000  2921.000000  2921.000000
# mean             6.612924       0.115923    62.868196    44.665526
# std              3.181191       0.357859    20.624515    18.896910
# min              0.000000       0.000000     0.000000   -14.000000
# 25%              4.250000       0.000000    47.000000    30.000000
# 50%              6.260000       0.000000    66.000000    46.000000
# 75%              8.500000       0.050000    81.000000    61.000000
# max             20.130000       9.990000   103.000000    99.000000
#
#        Fastest 2 minute wind speed  Fastest 5 second wind speed  Fog/Ice fog  \
# count                  2921.000000                  2921.000000  2921.000000
# mean                     16.705717                    23.338959     0.491955
# std                       5.866211                     8.730218     0.500021
# min                       0.000000                     0.000000     0.000000
# 25%                      13.000000                    17.000000     0.000000
# 50%                      16.100000                    21.900000     0.000000
# 75%                      19.900000                    28.000000     1.000000
# max                      52.100000                   130.000000     1.000000
#
#        Heavy freezing fog      Thunder        Glaze   Smoke/Haze  \
# count         2921.000000  2921.000000  2921.000000  2921.000000
# mean             0.044163     0.133858     0.008216     0.183156
# std              0.205492     0.340558     0.090286     0.386861
# min              0.000000     0.000000     0.000000     0.000000
# 25%              0.000000     0.000000     0.000000     0.000000
# 50%              0.000000     0.000000     0.000000     0.000000
# 75%              0.000000     0.000000     0.000000     0.000000
# max              1.000000     1.000000     1.000000     1.000000
#
#        Blowing/Drifting Snow  Power Outage
# count            2921.000000   2921.000000
# mean                0.001027      0.017460
# std                 0.032037      0.130999
# min                 0.000000      0.000000
# 25%                 0.000000      0.000000
# 50%                 0.000000      0.000000
# 75%                 0.000000      0.000000
# max                 1.000000      1.000000

# %%
#Add columns for wind squared
df['Avg Wind Speed Squared'] = pd.Series(np.square(df['Average Wind Speed']), index=df.index)
df['5 second wind speed squared'] = pd.Series(np.square(df['Fastest 5 second wind speed']));
df['2 min wind speed squared'] = pd.Series(np.square(df['Fastest 2 minute wind speed']));

# %%
df = df[['Power Outage', 'Precipitation', 'TMAX','TMIN','5 second wind speed squared', '2 min wind speed squared','Avg Wind Speed Squared','Fog/Ice fog', 'Heavy freezing fog', 'Thunder','Smoke/Haze']];

# %%
df.describe()
# Out:
#        Power Outage  Precipitation         TMAX         TMIN  \
# count   2921.000000    2921.000000  2921.000000  2921.000000
# mean       0.017460       0.115923    62.868196    44.665526
# std        0.130999       0.357859    20.624515    18.896910
# min        0.000000       0.000000     0.000000   -14.000000
# 25%        0.000000       0.000000    47.000000    30.000000
# 50%        0.000000       0.000000    66.000000    46.000000
# 75%        0.000000       0.050000    81.000000    61.000000
# max        1.000000       9.990000   103.000000    99.000000
#
#        5 second wind speed squared  2 min wind speed squared  \
# count                  2921.000000               2921.000000
# mean                    620.897628                313.481643
# std                     554.395829                233.336400
# min                       0.000000                  0.000000
# 25%                     289.000000                169.000000
# 50%                     479.610000                259.210000
# 75%                     784.000000                396.010000
# max                   16900.000000               2714.410000
#
#        Avg Wind Speed Squared  Fog/Ice fog  Heavy freezing fog      Thunder  \
# count             2921.000000  2921.000000         2921.000000  2921.000000
# mean                53.847271     0.491955            0.044163     0.133858
# std                 51.293047     0.500021            0.205492     0.340558
# min                  0.000000     0.000000            0.000000     0.000000
# 25%                 18.062500     0.000000            0.000000     0.000000
# 50%                 39.187600     0.000000            0.000000     0.000000
# 75%                 72.250000     1.000000            0.000000     0.000000
# max                405.216900     1.000000            1.000000     1.000000
#
#         Smoke/Haze
# count  2921.000000
# mean      0.183156
# std       0.386861
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
#Under sample based on Cluster Centroids
df_ML = pdml.ModelFrame(df, target = 'Power Outage')
df_ML.target_name
df_ML.target.value_counts()
sampler = df_ML.imbalance.under_sampling.ClusterCentroids()
sampled = df_ML.fit_sample(sampler);
sampled.target.value_counts()
finalData = pd.DataFrame(sampled);
finalData.describe()
# Out:
#        Power Outage  Precipitation        TMAX        TMIN  \
# count    102.000000     102.000000  102.000000  102.000000
# mean       0.500000       0.229499   70.052988   51.570836
# std        0.502469       0.439884   17.527704   15.782938
# min        0.000000       0.000000   30.000000   17.000000
# 25%        0.000000       0.003438   57.036638   39.605000
# 50%        0.500000       0.079805   71.605330   52.250000
# 75%        1.000000       0.229531   83.750000   66.000000
# max        1.000000       3.140000  101.000000   77.000000
#
#        5 second wind speed squared  2 min wind speed squared  \
# count                   102.000000                102.000000
# mean                   1388.779459                557.481620
# std                    1854.680812                447.597866
# min                       0.000000                 67.787647
# 25%                     479.610000                225.000000
# 50%                    1024.000000                441.000000
# 75%                    1625.889375                813.294792
# max                   16900.000000               2714.410000
#
#        Avg Wind Speed Squared  Fog/Ice fog  Heavy freezing fog       Thunder  \
# count              102.000000   102.000000          102.000000  1.020000e+02
# mean                76.232786     0.584536            0.048654  3.511007e-01
# std                 72.092277     0.380586            0.170275  4.220276e-01
# min                  0.000000     0.000000            0.000000 -2.775558e-17
# 25%                 28.233224     0.372351            0.000000  0.000000e+00
# 50%                 48.024900     0.594289            0.000000  1.180556e-01
# 75%                 95.841004     1.000000            0.033333  1.000000e+00
# max                353.064100     1.000000            1.000000  1.000000e+00
#
#        Smoke/Haze
# count  102.000000
# mean     0.217052
# std      0.325566
# min      0.000000
# 25%      0.000000
# 50%      0.102632
# 75%      0.232018
# max      1.000000

# %%
finalData = finalData[['Power Outage','5 second wind speed squared','Avg Wind Speed Squared','2 min wind speed squared','Fog/Ice fog','Heavy freezing fog','Thunder']];

# %%
#Normalize data
scaledData = preprocessing.MinMaxScaler().fit_transform(finalData.values);
finalData = pd.DataFrame(scaledData, index = finalData.index, columns = finalData.columns);
finalData.to_csv('Indiana Final Data', index=False);

# %%
print("Done!");
# Out:
# Done!
